# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Accidentes de tráfico en Madrid"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "analisis exploratorio de los accidentes ocurridos en Madrid en el año 2023"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "qué grupo de edad tiene mas accidentes"

# %%
 hipotesis_2 = "en que barrio se producen más accidentes"
hipotesis_3 = "en qué franja horaria se producen más accidentes"
hipotesis_4 = "cuantos accidentes de media al dia"
hipotesis_5 = "hay mas accidentes cuando no esta despejado"
hipotesis_6 = "accidentes por sexos"

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
import numpy as np
from datetime import datetime 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df = pd.read_csv('C:/Users/Sengan/Desktop/2023_Accidentalidad.csv', sep=';')
fuente_1 = ""

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df.head(100)
# Out:
#    num_expediente       fecha      hora            localizacion numero  \
# 0     2023S000001  01/01/2023   1:15:00  AVDA. ALFONSO XIII, 33     33
# 1     2023S000001  01/01/2023   1:15:00  AVDA. ALFONSO XIII, 33     33
# 2     2023S000001  01/01/2023   1:15:00  AVDA. ALFONSO XIII, 33     33
# 3     2023S000001  01/01/2023   1:15:00  AVDA. ALFONSO XIII, 33     33
# 4     2023S000001  01/01/2023   1:15:00  AVDA. ALFONSO XIII, 33     33
# ..            ...         ...       ...                     ...    ...
# 95    2023S000049  01/01/2023  23:30:00       CALL. LEONESES, 4      4
# 96    2023S000049  01/01/2023  23:30:00       CALL. LEONESES, 4      4
# 97    2023S000052  02/01/2023   0:05:00       AVDA. CORDOBA, 45     45
# 98    2023S000052  02/01/2023   0:05:00       AVDA. CORDOBA, 45     45
# 99    2023S000054  02/01/2023   1:50:00        CALL. SAHARA, 58     58
#
#     cod_distrito            distrito                tipo_accidente  \
# ...

# %%
result=df.dtypes
result
# Out:
# num_expediente           object
# fecha                    object
# hora                     object
# localizacion             object
# numero                   object
# cod_distrito            float64
# distrito                 object
# tipo_accidente           object
# estado_meteorológico     object
# tipo_vehiculo            object
# tipo_persona             object
# rango_edad               object
# sexo                     object
# cod_lesividad           float64
# lesividad                object
# coordenada_x_utm        float64
# coordenada_y_utm        float64
# positiva_alcohol         object
# positiva_droga          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48830 entries, 0 to 48829
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   num_expediente        48830 non-null  object
#  1   fecha                 48830 non-null  object
#  2   hora                  48830 non-null  object
#  3   localizacion          48830 non-null  object
#  4   numero                48827 non-null  object
#  5   cod_distrito          48827 non-null  float64
#  6   distrito              48827 non-null  object
#  7   tipo_accidente        48830 non-null  object
#  8   estado_meteorológico  43127 non-null  object
#  9   tipo_vehiculo         48452 non-null  object
#  10  tipo_persona          48830 non-null  object
#  11  rango_edad            48830 non-null  object
#  12  sexo                  48830 non-null  object
#  13  cod_lesividad         25945 non-null  float64
#  14  lesividad             25945 non-null  object
# ...

# %%
df['fecha'] = df['fecha'].astype('datetime64[ns]')

# %%
df['hora'] = df['hora'].astype('datetime64[ns]')

df['hora'] = df['hora'].dt.time

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48830 entries, 0 to 48829
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   num_expediente        48830 non-null  object
#  1   fecha                 48830 non-null  datetime64[ns]
#  2   hora                  48830 non-null  object
#  3   localizacion          48830 non-null  object
#  4   numero                48827 non-null  object
#  5   cod_distrito          48827 non-null  float64
#  6   distrito              48827 non-null  object
#  7   tipo_accidente        48830 non-null  object
#  8   estado_meteorológico  43127 non-null  object
#  9   tipo_vehiculo         48452 non-null  object
#  10  tipo_persona          48830 non-null  object
#  11  rango_edad            48830 non-null  object
#  12  sexo                  48830 non-null  object
#  13  cod_lesividad         25945 non-null  float64
# ...

# %%
df['mes']=df['fecha'].dt.month
df
# Out:
#       num_expediente      fecha      hora  \
# 0        2023S000001 2023-01-01  01:15:00
# 1        2023S000001 2023-01-01  01:15:00
# 2        2023S000001 2023-01-01  01:15:00
# 3        2023S000001 2023-01-01  01:15:00
# 4        2023S000001 2023-01-01  01:15:00
# ...              ...        ...       ...
# 48825    2023S040267 2023-12-31  21:15:00
# 48826    2023S040267 2023-12-31  21:15:00
# 48827    2023S040277 2023-12-29  09:35:00
# 48828    2023S040277 2023-12-29  09:35:00
# 48829    2023S040290 2023-12-29  05:10:00
#
#                                          localizacion numero  cod_distrito  \
# 0                              AVDA. ALFONSO XIII, 33     33           5.0
# 1                              AVDA. ALFONSO XIII, 33     33           5.0
# 2                              AVDA. ALFONSO XIII, 33     33           5.0
# 3                              AVDA. ALFONSO XIII, 33     33           5.0
# 4                              AVDA. ALFONSO XIII, 33     33           5.0
# ...

# %%
df['mes'] = df['mes'].replace({1:'Enero', 2: 'Febrero', 3: 'Marzo', 4:'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48830 entries, 0 to 48829
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   num_expediente        48830 non-null  object
#  1   fecha                 48830 non-null  datetime64[ns]
#  2   hora                  48830 non-null  object
#  3   localizacion          48830 non-null  object
#  4   numero                48827 non-null  object
#  5   cod_distrito          48827 non-null  float64
#  6   distrito              48827 non-null  object
#  7   tipo_accidente        48830 non-null  object
#  8   estado_meteorológico  43127 non-null  object
#  9   tipo_vehiculo         48452 non-null  object
#  10  tipo_persona          48830 non-null  object
#  11  rango_edad            48830 non-null  object
#  12  sexo                  48830 non-null  object
#  13  cod_lesividad         25945 non-null  float64
# ...

# %%
df
# Out:
#       num_expediente      fecha      hora  \
# 0        2023S000001 2023-01-01  01:15:00
# 1        2023S000001 2023-01-01  01:15:00
# 2        2023S000001 2023-01-01  01:15:00
# 3        2023S000001 2023-01-01  01:15:00
# 4        2023S000001 2023-01-01  01:15:00
# ...              ...        ...       ...
# 48825    2023S040267 2023-12-31  21:15:00
# 48826    2023S040267 2023-12-31  21:15:00
# 48827    2023S040277 2023-12-29  09:35:00
# 48828    2023S040277 2023-12-29  09:35:00
# 48829    2023S040290 2023-12-29  05:10:00
#
#                                          localizacion numero  cod_distrito  \
# 0                              AVDA. ALFONSO XIII, 33     33           5.0
# 1                              AVDA. ALFONSO XIII, 33     33           5.0
# 2                              AVDA. ALFONSO XIII, 33     33           5.0
# 3                              AVDA. ALFONSO XIII, 33     33           5.0
# 4                              AVDA. ALFONSO XIII, 33     33           5.0
# ...

# %%
valores_unicos = df['sexo'].unique()
print("Valores únicos en 'sexo':", valores_unicos)
# Out:
# Valores únicos en 'sexo': ['Mujer' 'Hombre' 'Desconocido']

# %%
conteo_valores = df['num_expediente'].value_counts()
print("\nConteo de valores en 'categoria':\n", conteo_valores)
# Out:
# Conteo de valores en 'categoria':
#  num_expediente
# 2023S039284    44
# 2023S019009    23
# 2023S034849    15
# 2023S036142    15
# 2023S004268    13
#                ..
# 2023S040264     1
# 2023S040261     1
# 2023S000019     1
# 2023S000009     1
# 2023S000007     1
# Name: count, Length: 20672, dtype: int64

# %%
conteo_valores = df['tipo_persona'].value_counts()
print("\nConteo de valores en 'categoria':\n", conteo_valores)
# Out:
# Conteo de valores en 'categoria':
#  tipo_persona
# Conductor    39151
# Pasajero      7893
# Peatón        1786
# Name: count, dtype: int64

# %%
df['distrito'].unique()
# Out:
# array(['CHAMARTÍN', 'SAN BLAS-CANILLEJAS', 'MONCLOA-ARAVACA', 'CENTRO',
#        'TETUÁN', 'VILLAVERDE', 'LATINA', 'BARAJAS', 'FUENCARRAL-EL PARDO',
#        'ARGANZUELA', 'PUENTE DE VALLECAS', 'CARABANCHEL', 'CIUDAD LINEAL',
#        'HORTALEZA', 'USERA', 'SALAMANCA', 'MORATALAZ', 'CHAMBERÍ',
#        'RETIRO', 'VILLA DE VALLECAS', 'VICÁLVARO', nan], dtype=object)

# %%
distrito_dict = {
    1: ['CENTRO','LATINA'],
    2: ['RETIRO'],
    3: ['SALAMANCA','CHAMBERÍ'],
    4: 'nan',
    5: ['TETUÁN','CHAMARTÍN','ARGANZUELA','MONCLOA-ARAVACA'],
    6: 'nan',
    7: ['USERA','SAN BLAS-CANILLEJAS','MORATALAZ','CIUDAD LINEAL','BARAJAS','HORTALEZA','PUENTE DE VALLECAS', 'CARABANCHEL','VILLAVERDE','FUENCARRAL-EL PARDO','VICÁLVARO','VILLA DE VALLECAS'],
    8: 'nan',
    9: 'nan'}

# %%
df['distrito'] = df['distrito'].astype(str)

# %%
def obtener_zona(distrito):
    
    for zona, distritos in distrito_dict.items():
        if distrito in distritos:
            return zona
    return None

# %%
df['zona'] = df['distrito'].apply(obtener_zona)

# %%
df
# Out:
#       num_expediente      fecha      hora  \
# 0        2023S000001 2023-01-01  01:15:00
# 1        2023S000001 2023-01-01  01:15:00
# 2        2023S000001 2023-01-01  01:15:00
# 3        2023S000001 2023-01-01  01:15:00
# 4        2023S000001 2023-01-01  01:15:00
# ...              ...        ...       ...
# 48825    2023S040267 2023-12-31  21:15:00
# 48826    2023S040267 2023-12-31  21:15:00
# 48827    2023S040277 2023-12-29  09:35:00
# 48828    2023S040277 2023-12-29  09:35:00
# 48829    2023S040290 2023-12-29  05:10:00
#
#                                          localizacion numero  cod_distrito  \
# 0                              AVDA. ALFONSO XIII, 33     33           5.0
# 1                              AVDA. ALFONSO XIII, 33     33           5.0
# 2                              AVDA. ALFONSO XIII, 33     33           5.0
# 3                              AVDA. ALFONSO XIII, 33     33           5.0
# 4                              AVDA. ALFONSO XIII, 33     33           5.0
# ...

# %%
trafico_raw = pd.read_csv(r"c:\Users\Sengan\Desktop\intensidad_media_dias_laborables_2023-2024.csv", sep=';')
trafico_raw
# Out:
#              O. Tráfico, Transportes y Comunicaciones  Unnamed: 1  \
# 0                                  Intensidad Trafico         NaN
# 1                                                 NaN         NaN
# 2   1.1.B. Suma de las Intensidades medias de días...         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 Año         Mes
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8                                                2023       Enero
# 9                                                2023     Febrero
# 10                                               2023       Marzo
# 11                                               2023       Abril
# 12                                               2023        Mayo
# ...

# %%
trafico_mes = trafico_raw.loc[trafico_raw['O. Tráfico, Transportes y Comunicaciones'] == '2023']

trafico_mes = trafico_mes.rename(columns={'Unnamed: 1': 'mes'})

# %%
trafico_mes
# Out:
#    O. Tráfico, Transportes y Comunicaciones         mes Unnamed: 2 Unnamed: 3  \
# 8                                      2023       Enero  1.807.098    100.994
# 9                                      2023     Febrero  1.872.671    103.267
# 10                                     2023       Marzo  1.892.453    101.688
# 11                                     2023       Abril  1.936.848    107.298
# 12                                     2023        Mayo  1.970.976    105.762
# 13                                     2023       Junio  1.950.517    106.472
# 14                                     2023       Julio  1.769.663    104.198
# 15                                     2023      Agosto  1.317.587     96.586
# 16                                     2023  Septiembre  1.891.600    110.634
# 17                                     2023     Octubre  1.962.564    109.221
# 18                                     2023   Noviembre  1.910.288    109.582
# ...

# %%
trafico1=trafico_mes.iloc[1:,0:10]
trafico1
# Out:
#    O. Tráfico, Transportes y Comunicaciones         mes Unnamed: 2 Unnamed: 3  \
# 9                                      2023     Febrero  1.872.671    103.267
# 10                                     2023       Marzo  1.892.453    101.688
# 11                                     2023       Abril  1.936.848    107.298
# 12                                     2023        Mayo  1.970.976    105.762
# 13                                     2023       Junio  1.950.517    106.472
# 14                                     2023       Julio  1.769.663    104.198
# 15                                     2023      Agosto  1.317.587     96.586
# 16                                     2023  Septiembre  1.891.600    110.634
# 17                                     2023     Octubre  1.962.564    109.221
# 18                                     2023   Noviembre  1.910.288    109.582
# 19                                     2023   Diciembre  1.938.102    106.171
#
# ...

# %%
trafico2=trafico_mes.iloc[:,1:10]
trafico2
# Out:
#            mes Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 8        Enero  1.807.098    100.994    224.834    362.963    189.928
# 9      Febrero  1.872.671    103.267    234.830    377.710    197.180
# 10       Marzo  1.892.453    101.688    243.207    380.049    193.387
# 11       Abril  1.936.848    107.298    248.430    386.098    199.339
# 12        Mayo  1.970.976    105.762    248.589    413.139    206.168
# 13       Junio  1.950.517    106.472    250.664    387.342    207.490
# 14       Julio  1.769.663    104.198    237.217    354.925    180.046
# 15      Agosto  1.317.587     96.586    170.782    260.972    126.559
# 16  Septiembre  1.891.600    110.634    247.597    383.272    201.814
# 17     Octubre  1.962.564    109.221    247.038    396.708    207.692
# 18   Noviembre  1.910.288    109.582    246.405    372.216    212.265
# 19   Diciembre  1.938.102    106.171    249.418    371.376    211.614
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9
# ...

# %%
trafico2 = trafico2.rename(columns={'Unnamed: 2': 'promedio','Unnamed: 3': '1', 'Unnamed: 4': '2','Unnamed: 5': '3','Unnamed: 6': '4','Unnamed: 7': '5','Unnamed: 8': '6','Unnamed: 9': '7'})
trafico2
# Out:
#            mes   promedio        1        2        3        4        5  \
# 8        Enero  1.807.098  100.994  224.834  362.963  189.928  385.221
# 9      Febrero  1.872.671  103.267  234.830  377.710  197.180  404.577
# 10       Marzo  1.892.453  101.688  243.207  380.049  193.387  426.250
# 11       Abril  1.936.848  107.298  248.430  386.098  199.339  435.653
# 12        Mayo  1.970.976  105.762  248.589  413.139  206.168  434.407
# 13       Junio  1.950.517  106.472  250.664  387.342  207.490  439.869
# 14       Julio  1.769.663  104.198  237.217  354.925  180.046  394.413
# 15      Agosto  1.317.587   96.586  170.782  260.972  126.559  279.008
# 16  Septiembre  1.891.600  110.634  247.597  383.272  201.814  433.107
# 17     Octubre  1.962.564  109.221  247.038  396.708  207.692  438.690
# 18   Noviembre  1.910.288  109.582  246.405  372.216  212.265  403.138
# 19   Diciembre  1.938.102  106.171  249.418  371.376  211.614  436.112
#
#           6        7
# 8   198.850  318.627
# ...

# %%
trafico2=trafico2.iloc[:,0:]

trafico2
# Out:
#            mes   promedio        1        2        3        4        5  \
# 8        Enero  1.807.098  100.994  224.834  362.963  189.928  385.221
# 9      Febrero  1.872.671  103.267  234.830  377.710  197.180  404.577
# 10       Marzo  1.892.453  101.688  243.207  380.049  193.387  426.250
# 11       Abril  1.936.848  107.298  248.430  386.098  199.339  435.653
# 12        Mayo  1.970.976  105.762  248.589  413.139  206.168  434.407
# 13       Junio  1.950.517  106.472  250.664  387.342  207.490  439.869
# 14       Julio  1.769.663  104.198  237.217  354.925  180.046  394.413
# 15      Agosto  1.317.587   96.586  170.782  260.972  126.559  279.008
# 16  Septiembre  1.891.600  110.634  247.597  383.272  201.814  433.107
# 17     Octubre  1.962.564  109.221  247.038  396.708  207.692  438.690
# 18   Noviembre  1.910.288  109.582  246.405  372.216  212.265  403.138
# 19   Diciembre  1.938.102  106.171  249.418  371.376  211.614  436.112
#
#           6        7
# 8   198.850  318.627
# ...

# %%
trafico2=trafico2.set_index('mes')

# %%
trafico2=trafico2.iloc[:,1:]
trafico2
# Out:
#                   1        2        3        4        5        6        7
# mes
# Enero       100.994  224.834  362.963  189.928  385.221  198.850  318.627
# Febrero     103.267  234.830  377.710  197.180  404.577  203.704  325.261
# Marzo       101.688  243.207  380.049  193.387  426.250  199.597  321.551
# Abril       107.298  248.430  386.098  199.339  435.653  204.523  328.337
# Mayo        105.762  248.589  413.139  206.168  434.407  202.644  332.825
# Junio       106.472  250.664  387.342  207.490  439.869  204.867  326.698
# Julio       104.198  237.217  354.925  180.046  394.413  184.248  290.717
# Agosto       96.586  170.782  260.972  126.559  279.008  132.695  231.939
# Septiembre  110.634  247.597  383.272  201.814  433.107  166.806  321.970
# Octubre     109.221  247.038  396.708  207.692  438.690  203.652  332.351
# Noviembre   109.582  246.405  372.216  212.265  403.138  219.245  320.005
# Diciembre   106.171  249.418  371.376  211.614  436.112  210.516  325.611

# %%
trafico2=trafico2.reset_index()

# %%
def obtener_zona(distrito):
    for zona, distritos in distrito_dict.items():
        if distrito in distritos:
            return zona
    return None

# %%
trafico_melted1 = trafico2.melt(id_vars=['mes'], var_name='zona', value_name='trafico')
trafico_melted1
# Out:
#            mes zona  trafico
# 0        Enero    1  100.994
# 1      Febrero    1  103.267
# 2        Marzo    1  101.688
# 3        Abril    1  107.298
# 4         Mayo    1  105.762
# ..         ...  ...      ...
# 79      Agosto    7  231.939
# 80  Septiembre    7  321.970
# 81     Octubre    7  332.351
# 82   Noviembre    7  320.005
# 83   Diciembre    7  325.611
#
# [84 rows x 3 columns]

# %%
trafico_melted1['zona'] = trafico_melted1['zona'].astype(str)
df['zona'] = df['zona'].astype(str)
df['mes'] = df['mes'].astype(str)
trafico_melted1['columna_concat'] = trafico_melted1['mes'] + trafico_melted1['zona']
trafico_melted1['mes'].unique()
# Out:
# array(['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio',
#        'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
#       dtype=object)

# %%
trafico_melted1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mes             84 non-null     object
#  1   zona            84 non-null     object
#  2   trafico         84 non-null     object
#  3   columna_concat  84 non-null     object
# dtypes: object(4)
# memory usage: 2.8+ KB

# %%
df['zona'] = df['zona'].astype(str)
df['mes'] = df['mes'].astype(str)

# %%
accidentes2 =pd.merge(df,trafico_melted1, on=['mes', 'zona'], how='left')
accidentes2
# Out:
#       num_expediente      fecha      hora  \
# 0        2023S000001 2023-01-01  01:15:00
# 1        2023S000001 2023-01-01  01:15:00
# 2        2023S000001 2023-01-01  01:15:00
# 3        2023S000001 2023-01-01  01:15:00
# 4        2023S000001 2023-01-01  01:15:00
# ...              ...        ...       ...
# 48825    2023S040267 2023-12-31  21:15:00
# 48826    2023S040267 2023-12-31  21:15:00
# 48827    2023S040277 2023-12-29  09:35:00
# 48828    2023S040277 2023-12-29  09:35:00
# 48829    2023S040290 2023-12-29  05:10:00
#
#                                          localizacion numero  cod_distrito  \
# 0                              AVDA. ALFONSO XIII, 33     33           5.0
# 1                              AVDA. ALFONSO XIII, 33     33           5.0
# 2                              AVDA. ALFONSO XIII, 33     33           5.0
# 3                              AVDA. ALFONSO XIII, 33     33           5.0
# 4                              AVDA. ALFONSO XIII, 33     33           5.0
# ...

# %%
accidentes2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48830 entries, 0 to 48829
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   num_expediente        48830 non-null  object
#  1   fecha                 48830 non-null  datetime64[ns]
#  2   hora                  48830 non-null  object
#  3   localizacion          48830 non-null  object
#  4   numero                48827 non-null  object
#  5   cod_distrito          48827 non-null  float64
#  6   distrito              48830 non-null  object
#  7   tipo_accidente        48830 non-null  object
#  8   estado_meteorológico  43127 non-null  object
#  9   tipo_vehiculo         48452 non-null  object
#  10  tipo_persona          48830 non-null  object
#  11  rango_edad            48830 non-null  object
#  12  sexo                  48830 non-null  object
#  13  cod_lesividad         25945 non-null  float64
# ...

# %%
temperatura1 = pd.read_csv(r"C:\Users\Sengan\Desktop\tiempo1º.csv", sep=',')
temperatura1
# Out:
#           fecha  indicativo          nombre provincia  altitud  tmed prec  \
# 0    2023-01-01        3195  MADRID, RETIRO    MADRID      667  11,3  0,1
# 1    2023-01-02        3195  MADRID, RETIRO    MADRID      667  10,4  0,0
# 2    2023-01-03        3195  MADRID, RETIRO    MADRID      667   9,0  0,0
# 3    2023-01-04        3195  MADRID, RETIRO    MADRID      667   7,4  0,0
# 4    2023-01-05        3195  MADRID, RETIRO    MADRID      667   7,3  0,0
# ..          ...         ...             ...       ...      ...   ...  ...
# 177  2023-06-27        3195  MADRID, RETIRO    MADRID      667  28,6  0,0
# 178  2023-06-28        3195  MADRID, RETIRO    MADRID      667  28,9  0,0
# 179  2023-06-29        3195  MADRID, RETIRO    MADRID      667  28,1  0,0
# 180  2023-06-30        3195  MADRID, RETIRO    MADRID      667  23,0  0,0
# 181  2023-07-01        3195  MADRID, RETIRO    MADRID      667  24,8  0,0
#
#      tmin horatmin  tmax  ... horaracha  presMax horaPresMax presMin  \
# ...

# %%
temperatura2 = pd.read_csv(r"C:\Users\Sengan\Desktop\tiempo2º.csv", sep=',')
temperatura2
# Out:
#           fecha  indicativo          nombre provincia  altitud  tmed prec  \
# 0    2023-07-02        3195  MADRID, RETIRO    MADRID      667  27,4  0,0
# 1    2023-07-03        3195  MADRID, RETIRO    MADRID      667  28,7  0,0
# 2    2023-07-04        3195  MADRID, RETIRO    MADRID      667  27,0  0,0
# 3    2023-07-05        3195  MADRID, RETIRO    MADRID      667  27,2  0,0
# 4    2023-07-06        3195  MADRID, RETIRO    MADRID      667  27,6  0,0
# ..          ...         ...             ...       ...      ...   ...  ...
# 178  2023-12-27        3195  MADRID, RETIRO    MADRID      667   4,6  0,0
# 179  2023-12-28        3195  MADRID, RETIRO    MADRID      667   4,0  0,0
# 180  2023-12-29        3195  MADRID, RETIRO    MADRID      667   6,1  0,0
# 181  2023-12-30        3195  MADRID, RETIRO    MADRID      667   6,2  0,0
# 182  2023-12-31        3195  MADRID, RETIRO    MADRID      667   7,2  0,0
#
#      tmin horatmin  tmax  ... horaracha  presMax horaPresMax presMin  \
# ...

# %%
temperatura = pd.concat([temperatura1, temperatura2], ignore_index=True)
temperatura
# Out:
#           fecha  indicativo          nombre provincia  altitud  tmed prec  \
# 0    2023-01-01        3195  MADRID, RETIRO    MADRID      667  11,3  0,1
# 1    2023-01-02        3195  MADRID, RETIRO    MADRID      667  10,4  0,0
# 2    2023-01-03        3195  MADRID, RETIRO    MADRID      667   9,0  0,0
# 3    2023-01-04        3195  MADRID, RETIRO    MADRID      667   7,4  0,0
# 4    2023-01-05        3195  MADRID, RETIRO    MADRID      667   7,3  0,0
# ..          ...         ...             ...       ...      ...   ...  ...
# 360  2023-12-27        3195  MADRID, RETIRO    MADRID      667   4,6  0,0
# 361  2023-12-28        3195  MADRID, RETIRO    MADRID      667   4,0  0,0
# 362  2023-12-29        3195  MADRID, RETIRO    MADRID      667   6,1  0,0
# 363  2023-12-30        3195  MADRID, RETIRO    MADRID      667   6,2  0,0
# 364  2023-12-31        3195  MADRID, RETIRO    MADRID      667   7,2  0,0
#
#      tmin horatmin  tmax  ... horaracha  presMax horaPresMax presMin  \
# ...

# %%
temperatura=temperatura[['fecha','tmed']]
temperatura
# Out:
#           fecha  tmed
# 0    2023-01-01  11,3
# 1    2023-01-02  10,4
# 2    2023-01-03   9,0
# 3    2023-01-04   7,4
# 4    2023-01-05   7,3
# ..          ...   ...
# 360  2023-12-27   4,6
# 361  2023-12-28   4,0
# 362  2023-12-29   6,1
# 363  2023-12-30   6,2
# 364  2023-12-31   7,2
#
# [365 rows x 2 columns]

# %%
temperatura['fecha'] = temperatura['fecha'].astype('datetime64[ns]')
temperatura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   365 non-null    datetime64[ns]
#  1   tmed    365 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 5.8+ KB
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\944732397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temperatura['fecha'] = temperatura['fecha'].astype('datetime64[ns]')

# %%
accidentes2.set_index('fecha')
accidentes2
# Out:
#       num_expediente      fecha      hora  \
# 0        2023S000001 2023-01-01  01:15:00
# 1        2023S000001 2023-01-01  01:15:00
# 2        2023S000001 2023-01-01  01:15:00
# 3        2023S000001 2023-01-01  01:15:00
# 4        2023S000001 2023-01-01  01:15:00
# ...              ...        ...       ...
# 48825    2023S040267 2023-12-31  21:15:00
# 48826    2023S040267 2023-12-31  21:15:00
# 48827    2023S040277 2023-12-29  09:35:00
# 48828    2023S040277 2023-12-29  09:35:00
# 48829    2023S040290 2023-12-29  05:10:00
#
#                                          localizacion numero  cod_distrito  \
# 0                              AVDA. ALFONSO XIII, 33     33           5.0
# 1                              AVDA. ALFONSO XIII, 33     33           5.0
# 2                              AVDA. ALFONSO XIII, 33     33           5.0
# 3                              AVDA. ALFONSO XIII, 33     33           5.0
# 4                              AVDA. ALFONSO XIII, 33     33           5.0
# ...

# %%
accidentes3 =pd.merge(accidentes2,temperatura, on=['fecha'], how='left')

# %%
pd.set_option('display.max_columns', None)
accidentes3
# Out:
#       num_expediente      fecha      hora  \
# 0        2023S000001 2023-01-01  01:15:00
# 1        2023S000001 2023-01-01  01:15:00
# 2        2023S000001 2023-01-01  01:15:00
# 3        2023S000001 2023-01-01  01:15:00
# 4        2023S000001 2023-01-01  01:15:00
# ...              ...        ...       ...
# 48825    2023S040267 2023-12-31  21:15:00
# 48826    2023S040267 2023-12-31  21:15:00
# 48827    2023S040277 2023-12-29  09:35:00
# 48828    2023S040277 2023-12-29  09:35:00
# 48829    2023S040290 2023-12-29  05:10:00
#
#                                          localizacion numero  cod_distrito  \
# 0                              AVDA. ALFONSO XIII, 33     33           5.0
# 1                              AVDA. ALFONSO XIII, 33     33           5.0
# 2                              AVDA. ALFONSO XIII, 33     33           5.0
# 3                              AVDA. ALFONSO XIII, 33     33           5.0
# 4                              AVDA. ALFONSO XIII, 33     33           5.0
# ...

# %%
atencion = {
    'leve': [
        'Atención en urgencias sin posterior ingreso',
        'Ingreso inferior o igual a 24 horas',
        'Asistencia sanitaria ambulatoria con posterioridad',
        'Asistencia sanitaria inmediata en centro de salud o mutua',
        'Asistencia sanitaria sólo en el lugar del accidente'
    ],
    'grave': ['Ingreso superior a 24 horas'],
    'fallecido': ['Fallecido 24 horas'],
    'sin asistencia sanitaria': ['Sin asistencia sanitaria'],
    'se desconoce': ['Se desconoce'],
    'Nan': [None]  # Manejo del valor nan
}

# %%
mapeo_lesividad = {valor: clave for clave, lista in atencion.items() for valor in lista}

# %%
def obtener_gravedad(lesividad):
    return mapeo_lesividad.get(lesividad, 'se desconoce')

# %%
accidentes3['lesividad'] = accidentes3['lesividad'].apply(obtener_gravedad)

# %%
accidentes3['lesividad'].unique()
# Out:
# array(['sin asistencia sanitaria', 'leve', 'se desconoce', 'grave',
#        'fallecido'], dtype=object)

# %%
accidentes3
# Out:
#       num_expediente      fecha      hora  \
# 0        2023S000001 2023-01-01  01:15:00
# 1        2023S000001 2023-01-01  01:15:00
# 2        2023S000001 2023-01-01  01:15:00
# 3        2023S000001 2023-01-01  01:15:00
# 4        2023S000001 2023-01-01  01:15:00
# ...              ...        ...       ...
# 48825    2023S040267 2023-12-31  21:15:00
# 48826    2023S040267 2023-12-31  21:15:00
# 48827    2023S040277 2023-12-29  09:35:00
# 48828    2023S040277 2023-12-29  09:35:00
# 48829    2023S040290 2023-12-29  05:10:00
#
#                                          localizacion numero  cod_distrito  \
# 0                              AVDA. ALFONSO XIII, 33     33           5.0
# 1                              AVDA. ALFONSO XIII, 33     33           5.0
# 2                              AVDA. ALFONSO XIII, 33     33           5.0
# 3                              AVDA. ALFONSO XIII, 33     33           5.0
# 4                              AVDA. ALFONSO XIII, 33     33           5.0
# ...

# %%
accidentes4= accidentes3.drop(['positiva_droga','columna_concat'],axis=1)
accidentes4.head()
# Out:
#   num_expediente      fecha      hora            localizacion numero  \
# 0    2023S000001 2023-01-01  01:15:00  AVDA. ALFONSO XIII, 33     33
# 1    2023S000001 2023-01-01  01:15:00  AVDA. ALFONSO XIII, 33     33
# 2    2023S000001 2023-01-01  01:15:00  AVDA. ALFONSO XIII, 33     33
# 3    2023S000001 2023-01-01  01:15:00  AVDA. ALFONSO XIII, 33     33
# 4    2023S000001 2023-01-01  01:15:00  AVDA. ALFONSO XIII, 33     33
#
#    cod_distrito   distrito tipo_accidente estado_meteorológico tipo_vehiculo  \
# 0           5.0  CHAMARTÍN        Alcance            Despejado  Todo terreno
# 1           5.0  CHAMARTÍN        Alcance            Despejado  Todo terreno
# 2           5.0  CHAMARTÍN        Alcance            Despejado  Todo terreno
# 3           5.0  CHAMARTÍN        Alcance            Despejado  Todo terreno
# 4           5.0  CHAMARTÍN        Alcance            Despejado  Todo terreno
#
#   tipo_persona       rango_edad    sexo  cod_lesividad  \
# ...

# %%
accidentes4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48830 entries, 0 to 48829
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   num_expediente        48830 non-null  object
#  1   fecha                 48830 non-null  datetime64[ns]
#  2   hora                  48830 non-null  object
#  3   localizacion          48830 non-null  object
#  4   numero                48827 non-null  object
#  5   cod_distrito          48827 non-null  float64
#  6   distrito              48830 non-null  object
#  7   tipo_accidente        48830 non-null  object
#  8   estado_meteorológico  43127 non-null  object
#  9   tipo_vehiculo         48452 non-null  object
#  10  tipo_persona          48830 non-null  object
#  11  rango_edad            48830 non-null  object
#  12  sexo                  48830 non-null  object
#  13  cod_lesividad         25945 non-null  float64
# ...

# %%
numero_accidentes= accidentes4['num_expediente'].nunique()
numero_accidentes
# Out:
# 20672

# %%
accidentes4['rango_edad'].unique()
# Out:
# array(['De 55 a 59 años', 'De 21 a 24 años', 'De 45 a 49 años',
#        'De 65 a 69 años', 'De 50 a 54 años', 'Desconocido',
#        'De 25 a 29 años', 'De 30 a 34 años', 'De 35 a 39 años',
#        'De 40 a 44 años', 'De 10 a 14 años', 'Más de 74 años',
#        'De 18 a 20 años', 'De 6 a 9 años', 'De 70 a 74 años',
#        'De 60 a 64 años', 'Menor de 5 años', 'De 15 a 17 años'],
#       dtype=object)

# %%
edad=accidentes4['rango_edad'].value_counts()
edad
# Out:
# rango_edad
# Desconocido        5337
# De 30 a 34 años    4870
# De 45 a 49 años    4852
# De 40 a 44 años    4821
# De 25 a 29 años    4635
# De 35 a 39 años    4550
# De 50 a 54 años    4371
# De 55 a 59 años    3640
# De 21 a 24 años    3118
# De 60 a 64 años    2348
# De 18 a 20 años    1540
# De 65 a 69 años    1149
# Más de 74 años     1141
# De 70 a 74 años     707
# Menor de 5 años     495
# De 10 a 14 años     473
# De 15 a 17 años     432
# De 6 a 9 años       351
# Name: count, dtype: int64

# %%
df_conductores = accidentes4.loc[df['tipo_persona'] == 'Conductor']
rango_a_eliminar = ['De 6 a 9 años', 'De 10 a 14 años', 'De 15 a 17 años']
df_conductores = df_conductores[~df_conductores['rango_edad'].isin(rango_a_eliminar)]
df_conductores['rango_edad'].value_counts()
# Out:
# rango_edad
# Desconocido        5296
# De 45 a 49 años    4166
# De 40 a 44 años    4123
# De 30 a 34 años    3986
# De 35 a 39 años    3839
# De 50 a 54 años    3781
# De 25 a 29 años    3608
# De 55 a 59 años    3089
# De 21 a 24 años    2238
# De 60 a 64 años    1924
# De 18 a 20 años     937
# De 65 a 69 años     826
# Más de 74 años      613
# De 70 a 74 años     481
# Name: count, dtype: int64

# %%
edad_filtrada = accidentes4[accidentes4['rango_edad'].notnull() & (accidentes4['rango_edad'] != 'Desconocido')]

# %%
conteo = edad_filtrada['rango_edad'].value_counts().reset_index()
conteo.columns = ['rango_edad', 'frecuencia']
conteo = conteo.sort_values(by='frecuencia', ascending=False)

# %%
plt.figure(figsize=(5, 5))
sns.barplot(data=conteo, x='rango_edad', y='frecuencia', palette='viridis')
plt.xticks(rotation=-85)  
plt.xlabel('Rango de Edad')
plt.ylabel('Frecuencia')
plt.title('personas involucradas en los accidentes por edad');
# Out:
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\622914857.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=conteo, x='rango_edad', y='frecuencia', palette='viridis')

# %%
edad_conductores_filtrada = df_conductores[df_conductores['rango_edad'].notnull() & (df_conductores['rango_edad'] != 'Desconocido')]

# %%
conteo1 = edad_conductores_filtrada['rango_edad'].value_counts().reset_index()
conteo1.columns = ['rango_edad', 'frecuencia']
conteo1 = conteo1.sort_values(by='frecuencia', ascending=False)

# %%
plt.figure(figsize=(5, 5))
sns.barplot(data=conteo1, x='rango_edad', y='frecuencia', palette='viridis')
plt.xticks(rotation=-85)  
plt.xlabel('Rango de Edad')
plt.ylabel('Frecuencia')
plt.title('Accidentes por rango Edad');
# Out:
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\2454069071.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=conteo1, x='rango_edad', y='frecuencia', palette='viridis')

# %%
labels = edad_conductores_filtrada['rango_edad'].value_counts().index
sizes = edad_conductores_filtrada['rango_edad'].value_counts().values
colores = sns.color_palette("viridis", len(labels))

# Crear las etiquetas de porcentaje, dejando en blanco aquellas menores al 6%
porcentajes = [f'{p:.1f}%' if p >= 6 else '' for p in 100 * sizes / sizes.sum()]

plt.figure(figsize=(10, 6))
plt.pie(sizes, colors=colores, autopct=lambda p: f'{p:.1f}%' if p >= 5 else '', startangle=90)
plt.title("Distribución por rango de edad")
plt.show()

# %%
df_filtrado1 = df_conductores[df_conductores['sexo'] != 'Desconocido']
sexo_counts = df_filtrado1['sexo'].value_counts()
colores = sns.color_palette("viridis", len(sexo_counts))

# %%
plt.figure(figsize=(5, 5))
plt.pie(sexo_counts,colors=colores, labels=sexo_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Proporción de Hombres y Mujeres en Accidentes')
plt.axis('equal')  # Para que el gráfico sea un círculo
plt.show()

# %%
df_conductores = df_conductores[(df_conductores['rango_edad'] != 'Desconocido') & (df_conductores['sexo'] != 'Desconocido')]
rango_sexo = df_conductores.groupby(['rango_edad', 'sexo']).size().reset_index(name='num_accidentes')

# %%
plt.figure(figsize=(5, 5))
sns.barplot(data=rango_sexo, x='rango_edad', y='num_accidentes', hue='sexo',palette='viridis')
plt.title('Número de Accidentes por Rango de Edad y Sexo')
plt.xlabel('Rango de Edad')
plt.ylabel('Número de Accidentes')
plt.legend(title='Sexo')
plt.xticks(rotation=-80)
plt.show()

# %%
df_filtrado2 = accidentes4[accidentes4['lesividad'] != 'se desconoce']
dolor = df_filtrado2['lesividad'].value_counts()

# %%
custom_order = ['grave', 'leve', 'fallecido', 'sin asistencia sanitaria']
dolor = dolor.reindex(custom_order)
colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700']

# %%
explode = [0.1] * len(dolor)
plt.figure(figsize=(5, 5))
plt.pie(dolor, labels=dolor.index, autopct='%1.1f%%', startangle=150, explode=explode, colors=colors)
plt.title('Gravedad del accidente')
plt.axis('equal')  
plt.show()

# %%
df_conductores = df_conductores[(df_conductores['rango_edad'] != 'Desconocido') & (df_conductores['sexo'] != 'Desconocido')]
lesividad_counts = df_conductores.groupby(['rango_edad', 'sexo', 'lesividad']).size().reset_index(name='num_accidentes')

# %%
lesividad_counts = lesividad_counts[~lesividad_counts['lesividad'].isin(['Desconocido', 'se desconoce'])]

# %%
plt.figure(figsize=(7, 7))
sns.barplot(data=lesividad_counts, x='rango_edad', y='num_accidentes', hue='lesividad', ci=None)
plt.title('Número de Accidentes por Lesividad y Rango de Edad')
plt.xlabel('Rango de Edad')
plt.ylabel('Número de Accidentes')
plt.xticks(rotation=-70)  
plt.legend(title='Lesividad')
plt.tight_layout()
# Out:
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\744419199.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=lesividad_counts, x='rango_edad', y='num_accidentes', hue='lesividad', ci=None)

# %%
lesividad_filtrada = lesividad_counts[lesividad_counts['lesividad'].isin(['grave', 'fallecido'])]

plt.figure(figsize=(5, 5))
sns.barplot(data=lesividad_filtrada, x='rango_edad', y='num_accidentes', hue='lesividad', ci=None)
plt.title('Número de Accidentes por Lesividad y Rango de Edad')
plt.xlabel('Rango de Edad')
plt.ylabel('Número de Accidentes')
plt.xticks(rotation=-70)  
plt.legend(title='Lesividad')
plt.tight_layout()
# Out:
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\2641376417.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=lesividad_filtrada, x='rango_edad', y='num_accidentes', hue='lesividad', ci=None)

# %%
sns.catplot(x="lesividad", y="rango_edad", data=df_conductores);

# %%
accidentes_agrupados = accidentes4.groupby('num_expediente').first()

# %%
accidentes_por_tipo = accidentes_agrupados['tipo_accidente'].value_counts()
accidentes_por_tipo
# Out:
# tipo_accidente
# Colisión fronto-lateral         4762
# Alcance                         4460
# Colisión lateral                3124
# Choque contra obstáculo fijo    3040
# Caída                           1860
# Atropello a persona             1409
# Colisión múltiple                715
# Otro                             498
# Colisión frontal                 457
# Solo salida de la vía            166
# Vuelco                            96
# Atropello a animal                83
# Despeñamiento                      2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=accidentes_por_tipo.index, y=accidentes_por_tipo.values, palette='viridis')
plt.title('Frecuencia de los tipos de accidente')
plt.xlabel('Tipo de accidente')
plt.ylabel('Número de accidentes')
plt.xticks(rotation=-70)
plt.tight_layout()
# Out:
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\2773501319.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=accidentes_por_tipo.index, y=accidentes_por_tipo.values, palette='viridis')

# %%
accidentes_por_mes = accidentes4['mes'].value_counts()
accidentes_por_mes
# Out:
# mes
# Diciembre     4498
# Abril         4461
# Noviembre     4455
# Octubre       4395
# Marzo         4266
# Mayo          4205
# Enero         4135
# Septiembre    4093
# Julio         3880
# Junio         3769
# Febrero       3654
# Agosto        3019
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=accidentes_por_mes.index, y=accidentes_por_mes.values, palette='viridis')
plt.title('Número de Accidentes por Mes')
plt.xlabel('Mes')
plt.ylabel('Número de Accidentes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.ylim(2000)
# Out:
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\2003023088.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=accidentes_por_mes.index, y=accidentes_por_mes.values, palette='viridis')
# (2000.0, 4722.9)

# %%
datos_agrupados = accidentes4.groupby(['distrito', 'mes'])['num_expediente'].nunique().reset_index()
datos_agrupados.rename(columns={'num_expediente': 'num_accidentes'}, inplace=True)

# %%
valores_a_eliminar = ['nan']

# %%
datos_agrupados = datos_agrupados[~datos_agrupados['mes'].isin(valores_a_eliminar)]
datos_agrupados = datos_agrupados[~datos_agrupados['distrito'].isin(valores_a_eliminar)]

# %%
palette = sns.color_palette("hsv", n_colors=len(datos_agrupados['distrito'].unique()))

# %%
mes_ordenado = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 
                'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
datos_agrupados['mes'] = pd.Categorical(datos_agrupados['mes'], categories=mes_ordenado, ordered=True)

# %%
palette = sns.color_palette('hsv', len(datos_agrupados['distrito'].unique()))

# %%
accidentes4 = accidentes4[accidentes4['distrito'] != 'nan']

# %%
accidentes_por_distrito = accidentes4.groupby('distrito')['num_expediente'].count().reset_index()
accidentes_por_distrito.columns = ['distrito', 'num_accidentes']
accidentes_por_distrito = accidentes_por_distrito.sort_values(by='num_accidentes', ascending=False)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=accidentes_por_distrito, x='distrito', y='num_accidentes', palette='viridis')
plt.title('Número de Accidentes por Distrito')
plt.xlabel('Distrito')
plt.ylabel('Número de Accidentes')
plt.xticks(rotation=-80)
plt.show()
# Out:
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\1948441167.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=accidentes_por_distrito, x='distrito', y='num_accidentes', palette='viridis')

# %%
vehiculos_accidentes = accidentes4.groupby('tipo_vehiculo')['num_expediente'].nunique().reset_index()
vehiculos_accidentes.columns = ['tipo_vehiculo', 'num_accidentes']

# %%
vehiculos_accidentes = vehiculos_accidentes[vehiculos_accidentes['num_accidentes'] > 50]

# %%
vehiculos_accidentes = vehiculos_accidentes.sort_values(by='num_accidentes', ascending=False)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='tipo_vehiculo', y='num_accidentes', data=vehiculos_accidentes,palette='viridis')
plt.title('Número de Accidentes por Tipo de Vehículo')
plt.xlabel('Tipo de Vehículo')
plt.ylabel('Número de Accidentes')
plt.xticks(rotation=-85);
# Out:
# C:\Users\Sengan\AppData\Local\Temp\ipykernel_1564\346603388.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='tipo_vehiculo', y='num_accidentes', data=vehiculos_accidentes,palette='viridis')

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import squarify

# %%
data = accidentes4.groupby("tipo_vehiculo").size().sort_values(ascending=False)


data = data[:10]
colors = plt.cm.viridis(np.linspace(0, 1, len(data)))


plt.figure(figsize=(15, 10))
squarify.plot(sizes=data.values, label=data.index, alpha=.8,color=colors)
plt.axis('off')
plt.title("Número de Accidentes por Distrito")
plt.show()

# %%
mes_ordenado = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 
                'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']


datos_agrupados['mes'] = pd.Categorical(datos_agrupados['mes'], categories=mes_ordenado, ordered=True)

plt.figure(figsize=(14, 8))


sns.lineplot(data=datos_agrupados, x='mes', y='num_accidentes', hue='distrito', marker='o')


plt.title('Número de Accidentes por Distrito y Mes')
plt.xlabel('Mes')
plt.ylabel('Número de Accidentes')
plt.xticks(rotation=45)
plt.legend(title='Distrito', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()
plt.tight_layout()

# %%
pip install nbformat
# Out:
# ...
#
# ...

# %%
pip install nbformat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

datos_agrupados['mes'] = pd.Categorical(datos_agrupados['mes'], categories=[
    'Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 
    'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'], ordered=True)
datos_agrupados = datos_agrupados.sort_values('mes')

fig = px.line(datos_agrupados, x='mes', y='num_accidentes', color='distrito',
              title='Número de Accidentes por Distrito y Mes',
              labels={'mes': 'Mes', 'num_accidentes': 'Número de Accidentes'})


fig.update_layout(xaxis_title='Mes', yaxis_title='Número de Accidentes', 
                  legend_title='Distrito', hovermode='x')


fig.show()
